# %%
###########################################
# --------------------------------------- #
# Primera Evaluación: Manglar El Sargento #
# --------------------------------------- #
#
# __________Jessica Isamar Uriarte Garcia #
# _______________________ 8 de Marzo 2018 #
###########################################


# Cargamos las bibliotecas necesarias al a memoria de trabajo

##### Para manejo de datos
import pandas as pd
##### Numerical python
import numpy as np
##### Graficas Matplotlib
import matplotlib.pyplot as plt
import sys
import datetime

# %%
# Cargamos la base de datos, ya editada en emacs (si es necesario) y lista para trabajarse
dfsal=pd.read_csv('sargento-salinidad-201117.csv',names=['Date','CondHigh','Temp','SConduct','Sal'], sep=',')
# Vemos la base de datos empezando de arriba (head)
dfsal.head()
# Out:
#                   Date  CondHigh   Temp  SConduct      Sal
# 1  10/26/2017 12:45:00   54525.5  25.21   54301.2  35.9195
# 2  10/26/2017 13:00:00   54525.5  24.91   54622.1  36.1588
# 3  10/26/2017 13:15:00   54525.5  24.82   54719.0  36.2311
# 4  10/26/2017 13:30:00   54525.5  24.76   54783.8  36.2794
# 5  10/26/2017 13:45:00   54525.5  24.75   54794.6  36.2875

# %%
# Le damos la estructura de datos
dfsal=pd.DataFrame(dfsal)
# Vemos los tipos de datos 
dfsal.dtypes
# Out:
# Date         object
# CondHigh    float64
# Temp        float64
# SConduct    float64
# Sal         float64
# dtype: object

# %%
dfsal['Fecha'] = pd.to_datetime(dfsal['Date'], format='%m/%d/%Y %H:%M:%S')
# Se borra la primera columna ya que no se ocupa.
dfsal=dfsal.drop(['Date'],1)
dfsal['month'] = dfsal['Fecha'].dt.month

# %%
dfsal.head()
# Out:
#    CondHigh   Temp  SConduct      Sal               Fecha  month
# 1   54525.5  25.21   54301.2  35.9195 2017-10-26 12:45:00     10
# 2   54525.5  24.91   54622.1  36.1588 2017-10-26 13:00:00     10
# 3   54525.5  24.82   54719.0  36.2311 2017-10-26 13:15:00     10
# 4   54525.5  24.76   54783.8  36.2794 2017-10-26 13:30:00     10
# 5   54525.5  24.75   54794.6  36.2875 2017-10-26 13:45:00     10

# %%
dfsal.dtypes
# Out:
# CondHigh           float64
# Temp               float64
# SConduct           float64
# Sal                float64
# Fecha       datetime64[ns]
# month                int64
# dtype: object

# %%
# Cargamos la base de datos, ya editada en emacs (si es necesario) y lista para trabajarse
dflevel=pd.read_csv('sargento_201117.csv',skiprows=1,names=['n','Date','kPa','Temp','Nivel'], sep=',')
dflevel['DateTime'] = pd.to_datetime(dflevel['Date'], format='%m/%d/%Y %H:%M:%S')
dflevel['month'] = dflevel['DateTime'].dt.month
dflevel=dflevel.drop(['Date'],1)
# Vemos la base de datos empezando de arriba (head)
dflevel.head()
# Out:
#    n      kPa    Temp  Nivel            DateTime  month
# 0  1  105.612  24.448 -0.150 2017-10-26 13:00:00     10
# 1  2  105.513  24.351 -0.160 2017-10-26 13:15:00     10
# 2  3  105.433  24.351 -0.168 2017-10-26 13:30:00     10
# 3  4  105.385  24.351 -0.173 2017-10-26 13:45:00     10
# 4  5  105.321  24.351 -0.179 2017-10-26 14:00:00     10

# %%
dflevel.tail()
# Out:
#          n      kPa   Temp  Nivel            DateTime  month
# 2390  2391  106.998  21.76 -0.012 2017-11-20 10:30:00     11
# 2391  2392  106.998  21.76 -0.012 2017-11-20 10:45:00     11
# 2392  2393  106.950  21.76 -0.017 2017-11-20 11:00:00     11
# 2393  2394  106.966  21.76 -0.015 2017-11-20 11:15:00     11
# 2394  2395  106.982  21.76 -0.014 2017-11-20 11:30:00     11

# %%
dflevel.describe()
# Out:
#                 n          kPa         Temp        Nivel        month
# count  2395.00000  2395.000000  2395.000000  2395.000000  2395.000000
# mean   1198.00000   107.429820    23.120315     0.030845    10.781211
# std     691.52127     2.371366     0.564123     0.235926     0.413512
# min       1.00000   104.229000    21.760000    -0.288000    10.000000
# 25%     599.50000   106.407000    22.525000    -0.071000    11.000000
# 50%    1198.00000   106.764000    23.388000    -0.035000    11.000000
# 75%    1796.50000   107.303000    23.484000     0.018500    11.000000
# max    2395.00000   118.641000    24.448000     1.146000    11.000000

# %%
dfsal.describe()
# Out:
#            CondHigh         Temp      SConduct          Sal        month
# count   2395.000000  2395.000000   2395.000000  2395.000000  2395.000000
# mean   54524.973027    23.317436  56385.960835    37.479086    10.780793
# std       11.874193     0.548286    620.837037     0.465969     0.413795
# min    54105.700000    21.490000  54301.200000    35.919500    10.000000
# 25%    54525.500000    22.730000  55949.700000    37.151400    11.000000
# 50%    54525.500000    23.490000  56185.600000    37.328300    11.000000
# 75%    54525.500000    23.700000  57053.700000    37.980300    11.000000
# max    54525.500000    25.210000  58398.700000    38.994200    11.000000

# %%
import seaborn as sns
ax = sns.boxplot(x='month', y='Nivel', data=dflevel)
plt.show()

# %%
import seaborn as sns
ax = sns.boxplot(x='month', y='Sal', data=dfsal)
plt.show()

# %%
import seaborn as sns
ax = sns.boxplot(x='month', y='Temp', data=dfsal)
plt.show()

# %%
dfsal.head()
# Out:
#    CondHigh   Temp  SConduct      Sal               Fecha  month
# 1   54525.5  25.21   54301.2  35.9195 2017-10-26 12:45:00     10
# 2   54525.5  24.91   54622.1  36.1588 2017-10-26 13:00:00     10
# 3   54525.5  24.82   54719.0  36.2311 2017-10-26 13:15:00     10
# 4   54525.5  24.76   54783.8  36.2794 2017-10-26 13:30:00     10
# 5   54525.5  24.75   54794.6  36.2875 2017-10-26 13:45:00     10

# %%
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

#tips = sns.load_dataset(x='Temp', y='Sal', data=dfsal)
g = sns.jointplot("Temp", "Sal", data=dfsal, kind="reg", color="r", size=7)
plt.show()
# Out:
# /Users/jessicauriarte/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

#tips = sns.load_dataset(x='Temp', y='Sal', data=dfsal)
g = sns.jointplot("Temp","Nivel", data=dflevel, kind="reg", color="b", size=7)
plt.show()
# Out:
# /Users/jessicauriarte/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)
df3=pd.concat([dflevel,dfsal],axis=1)
df4 = df3[['Sal','Nivel']]
#tips = sns.load_dataset(x='Temp', y='Sal', data=dfsal)
g = sns.jointplot("Nivel","Sal", data=df3, kind="reg", color="g", size=7)
plt.show()
# Out:
# /Users/jessicauriarte/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
df3.dtypes
# Out:
# n                  float64
# kPa                float64
# Temp               float64
# Nivel              float64
# DateTime    datetime64[ns]
# month              float64
# CondHigh           float64
# Temp               float64
# SConduct           float64
# Sal                float64
# Fecha       datetime64[ns]
# month              float64
# dtype: object

# %%
plt.figure(); dflevel.Nivel.plot();
plt.title("Variación del nivel del mar")
plt.ylabel("Nivel del mar (m)")
plt.grid(True)
plt.show()

# %%
plt.figure(); dflevel.Temp.plot();
plt.title("Variación de la temperatura")
plt.ylabel("C")
plt.grid(True)
plt.show()

# %%
plt.figure(); dfsal.Sal.plot();
plt.title("Variación de la salinidad")
plt.ylabel("partes por mil")
plt.grid(True)
plt.show()

# %%
df1 = dflevel[['Temp','Nivel']]
plt.figure(); df1.plot(); plt.legend(loc='best')
plt.title("Variación de la Temperatura y el nivel del mar")
plt.ylabel("Temp ºC /m")
plt.grid(True)
plt.show()

# %%
#df2 = dflevel[['Nivel']],dfsal[['Sal']]
#pd.concat([df_a,df_b], axis=1)
df3=pd.concat([dflevel,dfsal])
df4 = df3[['Sal','Nivel']]
plt.figure(); df4.plot(); plt.legend(loc='best')
plt.title("Variación de la salinidad y el nivel del mar")
plt.ylabel("Sal /m")
plt.grid(True)
plt.show()

# %%
df3=pd.concat([dflevel['Nivel'],dfsal['Sal']],axis=1)
#df4 = df3[['Sal','Nivel','n']]
plt.figure(); df3.plot(); plt.legend(loc='best');
plt.title("Variación de la salinidad y el nivel del mar")

plt.ylabel("Sal /m")
plt.grid(True)
# Los ultimos 5 dias fueron del 15 al 20 de Nov, entre los datos 1870 y 2395
plt.xlim([1870,2395])
plt.show()

# %%
df3=pd.concat([dflevel['Nivel'],dfsal['Temp']],axis=1)
#df4 = df3[['Sal','Nivel','n']]
plt.figure(); df3.plot(); plt.legend(loc='best')
plt.title("Variación de la temperatura y el nivel del mar")

plt.ylabel("C /m")
plt.grid(True)
# Los ultimos 5 dias fueron del 15 al 20 de Nov, entre los datos 1870 y 2395
plt.xlim([1870,2395])
plt.show()

# %%
df3=pd.concat([dflevel,dfsal])
df5 = dfsal[['Sal','Temp']]
plt.figure(); df5.plot(); plt.legend(loc='best')
plt.title("Variación de la salinidad y la temperatura")
plt.ylabel("Sal /C")
plt.grid(True)
plt.show()
